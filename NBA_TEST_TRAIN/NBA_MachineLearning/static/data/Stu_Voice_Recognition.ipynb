# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# # Voice Gender
# Gender Recognition by Voice and Speech Analysis
#
# This database was created to identify a voice as male or female, based upon acoustic properties of the voice and speech. The dataset consists of 3,168 recorded voice samples, collected from male and female speakers. The voice samples are pre-processed by acoustic analysis in R using the seewave and tuneR packages, with an analyzed frequency range of 0hz-280hz (human vocal range).
#
# ## The Dataset
# The following acoustic properties of each voice are measured and included within the CSV:
#
# * meanfreq: mean frequency (in kHz)
# * sd: standard deviation of frequency
# * median: median frequency (in kHz)
# * Q25: first quantile (in kHz)
# * Q75: third quantile (in kHz)
# * IQR: interquantile range (in kHz)
# * skew: skewness (see note in specprop description)
# * kurt: kurtosis (see note in specprop description)
# * sp.ent: spectral entropy
# * sfm: spectral flatness
# * mode: mode frequency
# * centroid: frequency centroid (see specprop)
# * peakf: peak frequency (frequency with highest energy)
# * meanfun: average of fundamental frequency measured across acoustic signal
# * minfun: minimum fundamental frequency measured across acoustic signal
# * maxfun: maximum fundamental frequency measured across acoustic signal
# * meandom: average of dominant frequency measured across acoustic signal
# * mindom: minimum of dominant frequency measured across acoustic signal
# * maxdom: maximum of dominant frequency measured across acoustic signal
# * dfrange: range of dominant frequency measured across acoustic signal
# * modindx: modulation index. Calculated as the accumulated absolute difference between adjacent measurements of fundamental frequencies divided by the frequency range
# * label: male or female

# %%
shots = pd.read_csv('DBexport_knicks_TESTING.csv')
shots
# Out:
#        game_id  game_event_id  player_id  action_number  shot_distance  loc_x  \
# 0     21800013             58    1628372             28              0      3
# 1     21800013             78    1628372             20             24   -173
# 2     21800013             94    1628372             12              0     -8
# 3     21800013            112    1628372             17             12    -13
# 4     21800013            245    1628372             22             17    -92
# 5     21800013            258    1628372             10             14    -54
# 6     21800013            267    1628372             19              5     -2
# 7     21800013            271    1628372             28              0      0
# 8     21800013            324    1628372             12              1     -2
# 9     21800013            333    1628372             19              2    -25
# 10    21800013            358    1628372              9              8    -62
# 11    21800013            364    1628372              7              1     -5
# 12    21800013            372    1628372             31              0     -7
# 13    21800013            403    1628372             13              1     11
# 14    21800013            421    1628372             31              1     -5
# 15    21800013            437    1628372             35             25    152
# 16    21800013            441    1628372             22             25    100
# 17    21800013            603    1628372             22             25    100
# 18    21800013            622    1628372              8              1     10
# 19    21800032             24    1628372             22             19    -93
# 20    21800032             45    1628372             20             28    -83
# 21    21800032            241    1628372             12              2    -22
# 22    21800032            250    1628372             22             19     52
# 23    21800032            392    1628372             20             24   -114
# 24    21800032            405    1628372             20             25     46
# 25    21800032            445    1628372             20             25    -95
# 26    21800032            619    1628372             19              1    -19
# 27    21800032            623    1628372             31              2     23
# 28    21800032            632    1628372             20             24    -43
# 29    21800032            661    1628372             12              0      9
# ...        ...            ...        ...            ...            ...    ...
# 2914  21801166             29    1629011              3              2     -7
# 2915  21801166            102    1629011              4              0      0
# 2916  21801166            271    1629011             36              0      0
# 2917  21801166            384    1629011             36              0      0
# 2918  21801166            453    1629011             24              3    -24
# 2919  21801166            519    1629011             28              1     -5
# 2920  21801166            570    1629011              3              1      0
# 2921  21801184             22    1629011             24              1      6
# 2922  21801184             76    1629011             23              0      0
# 2923  21801184            115    1629011             14              1     -8
# 2924  21801184            228    1629011             14              0     -8
# 2925  21801184            247    1629011              1              1     -4
# 2926  21801184            431    1629011              3              1     10
# 2927  21801204              7    1629011              1              1     -1
# 2928  21801204            106    1629011              1              1      0
# 2929  21801204            199    1629011              1              0     -5
# 2930  21801204            317    1629011             24              0      0
# 2931  21801204            550    1629011             37              0      0
# 2932  21801213             21    1629011             25              0     -6
# 2933  21801213             70    1629011              1              1    -13
# 2934  21801213             72    1629011             24              0      0
# 2935  21801213            314    1629011             14              0     -9
# 2936  21801213            416    1629011             20             15     11
# 2937  21801213            591    1629011              1              1    -16
# 2938  21801223             33    1629011             14              0      5
# 2939  21801223             36    1629011              1              0      4
# 2940  21801223             78    1629011              1              1      0
# 2941  21801223            177    1629011              1              1    -13
# 2942  21801223            193    1629011              1              0     -1
# 2943  21801223            489    1629011              1              0     -4
#
#       loc_y  shot_attempted_flag   event_type
# 0         5                    1    Made Shot
# 1       179                    1  Missed Shot
# 2         1                    1  Missed Shot
# 3       120                    1  Missed Shot
# 4       150                    1  Missed Shot
# 5       131                    1  Missed Shot
# 6        56                    1  Missed Shot
# 7         9                    1    Made Shot
# 8        13                    1    Made Shot
# 9        16                    1  Missed Shot
# 10       55                    1    Made Shot
# 11      -13                    1    Made Shot
# 12        2                    1  Missed Shot
# 13       11                    1  Missed Shot
# 14       16                    1  Missed Shot
# 15      204                    1    Made Shot
# 16      235                    1  Missed Shot
# 17      236                    1  Missed Shot
# 18        5                    1  Missed Shot
# 19      172                    1    Made Shot
# 20      272                    1  Missed Shot
# 21        7                    1    Made Shot
# 22      183                    1    Made Shot
# 23      222                    1  Missed Shot
# 24      253                    1    Made Shot
# 25      232                    1  Missed Shot
# 26        4                    1  Missed Shot
# 27       10                    1  Missed Shot
# 28      246                    1  Missed Shot
# 29        4                    1    Made Shot
# ...     ...                  ...          ...
# 2914     26                    1    Made Shot
# 2915      5                    1    Made Shot
# 2916     -6                    1    Made Shot
# 2917     -6                    1  Missed Shot
# 2918     28                    1  Missed Shot
# 2919     10                    1    Made Shot
# 2920     14                    1    Made Shot
# 2921      8                    1  Missed Shot
# 2922     -6                    1    Made Shot
# 2923     11                    1    Made Shot
# 2924      5                    1    Made Shot
# 2925     10                    1    Made Shot
# 2926     -9                    1    Made Shot
# 2927     10                    1    Made Shot
# 2928     11                    1    Made Shot
# 2929      2                    1    Made Shot
# 2930      9                    1    Made Shot
# 2931     -6                    1  Missed Shot
# 2932      0                    1    Made Shot
# 2933     15                    1  Missed Shot
# 2934     -6                    1    Made Shot
# 2935     -1                    1    Made Shot
# 2936    159                    1  Missed Shot
# 2937      4                    1  Missed Shot
# 2938      1                    1    Made Shot
# 2939      4                    1    Made Shot
# 2940     12                    1    Made Shot
# 2941     10                    1    Made Shot
# 2942      8                    1  Missed Shot
# 2943      0                    1    Made Shot
#
# [2944 rows x 9 columns]

# %%
# Assign X (data) and y (target)
X = shots.drop("event_type", axis=1)
y = shots["event_type"]
print(X.shape, y.shape)
# Out:
# (2944, 8) (2944,)

# %% [markdown]
# Split our data into training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %% [markdown]
# Create a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Fit (train) or model using the training data

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\antho\Anaconda4\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Validate the model using the test data

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.552536231884058
# Testing Data Score: 0.5271739130434783

# %% [markdown]
# Make predictions

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Missed Shot' 'Missed Shot' 'Missed Shot' 'Made Shot' 'Made Shot'
#  'Missed Shot' 'Missed Shot' 'Made Shot' 'Missed Shot' 'Made Shot']
# First 10 Actual labels: ['Missed Shot', 'Made Shot', 'Made Shot', 'Missed Shot', 'Missed Shot', 'Missed Shot', 'Made Shot', 'Made Shot', 'Made Shot', 'Made Shot']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#       Prediction       Actual
# 0    Missed Shot  Missed Shot
# 1    Missed Shot    Made Shot
# 2    Missed Shot    Made Shot
# 3      Made Shot  Missed Shot
# 4      Made Shot  Missed Shot
# 5    Missed Shot  Missed Shot
# 6    Missed Shot    Made Shot
# 7      Made Shot    Made Shot
# 8    Missed Shot    Made Shot
# 9      Made Shot    Made Shot
# 10   Missed Shot    Made Shot
# 11     Made Shot  Missed Shot
# 12     Made Shot    Made Shot
# 13     Made Shot    Made Shot
# 14   Missed Shot  Missed Shot
# 15   Missed Shot  Missed Shot
# 16     Made Shot  Missed Shot
# 17     Made Shot    Made Shot
# 18   Missed Shot  Missed Shot
# 19   Missed Shot    Made Shot
# 20   Missed Shot    Made Shot
# 21     Made Shot  Missed Shot
# 22   Missed Shot  Missed Shot
# 23   Missed Shot    Made Shot
# 24     Made Shot    Made Shot
# 25   Missed Shot  Missed Shot
# 26   Missed Shot  Missed Shot
# 27   Missed Shot    Made Shot
# 28     Made Shot    Made Shot
# 29   Missed Shot  Missed Shot
# ..           ...          ...
# 706  Missed Shot  Missed Shot
# 707  Missed Shot    Made Shot
# 708    Made Shot  Missed Shot
# 709    Made Shot    Made Shot
# 710  Missed Shot  Missed Shot
# 711    Made Shot  Missed Shot
# 712  Missed Shot  Missed Shot
# 713    Made Shot    Made Shot
# 714  Missed Shot    Made Shot
# 715  Missed Shot  Missed Shot
# 716  Missed Shot  Missed Shot
# 717  Missed Shot  Missed Shot
# 718  Missed Shot  Missed Shot
# 719  Missed Shot    Made Shot
# 720  Missed Shot  Missed Shot
# 721  Missed Shot    Made Shot
# 722    Made Shot  Missed Shot
# 723  Missed Shot  Missed Shot
# 724    Made Shot  Missed Shot
# 725  Missed Shot  Missed Shot
# 726    Made Shot    Made Shot
# 727  Missed Shot  Missed Shot
# 728    Made Shot  Missed Shot
# 729  Missed Shot  Missed Shot
# 730  Missed Shot  Missed Shot
# 731    Made Shot    Made Shot
# 732  Missed Shot  Missed Shot
# 733  Missed Shot    Made Shot
# 734    Made Shot    Made Shot
# 735    Made Shot  Missed Shot
#
# [736 rows x 2 columns]
