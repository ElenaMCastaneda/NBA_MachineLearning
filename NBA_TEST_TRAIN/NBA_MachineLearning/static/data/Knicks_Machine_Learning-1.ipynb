# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os

# %% [markdown]
# # Voice Gender
# Gender Recognition by Voice and Speech Analysis
#
# This database was created to identify a voice as male or female, based upon acoustic properties of the voice and speech. The dataset consists of 3,168 recorded voice samples, collected from male and female speakers. The voice samples are pre-processed by acoustic analysis in R using the seewave and tuneR packages, with an analyzed frequency range of 0hz-280hz (human vocal range).
#
# ## The Dataset
# The following acoustic properties of each voice are measured and included within the CSV:
#
# * meanfreq: mean frequency (in kHz)
# * sd: standard deviation of frequency
# * median: median frequency (in kHz)
# * Q25: first quantile (in kHz)
# * Q75: third quantile (in kHz)
# * IQR: interquantile range (in kHz)
# * skew: skewness (see note in specprop description)
# * kurt: kurtosis (see note in specprop description)
# * sp.ent: spectral entropy
# * sfm: spectral flatness
# * mode: mode frequency
# * centroid: frequency centroid (see specprop)
# * peakf: peak frequency (frequency with highest energy)
# * meanfun: average of fundamental frequency measured across acoustic signal
# * minfun: minimum fundamental frequency measured across acoustic signal
# * maxfun: maximum fundamental frequency measured across acoustic signal
# * meandom: average of dominant frequency measured across acoustic signal
# * mindom: minimum of dominant frequency measured across acoustic signal
# * maxdom: maximum of dominant frequency measured across acoustic signal
# * dfrange: range of dominant frequency measured across acoustic signal
# * modindx: modulation index. Calculated as the accumulated absolute difference between adjacent measurements of fundamental frequencies divided by the frequency range
# * label: male or female

# %%
shots = pd.read_csv('DBexport_knicks_TESTING.csv')
shots
# Out:
#       player_id  action_number   event_type
# 0       1628372             28    Made Shot
# 1       1628372             20  Missed Shot
# 2       1628372             12  Missed Shot
# 3       1628372             17  Missed Shot
# 4       1628372             22  Missed Shot
# 5       1628372             10  Missed Shot
# 6       1628372             19  Missed Shot
# 7       1628372             28    Made Shot
# 8       1628372             12    Made Shot
# 9       1628372             19  Missed Shot
# 10      1628372              9    Made Shot
# 11      1628372              7    Made Shot
# 12      1628372             31  Missed Shot
# 13      1628372             13  Missed Shot
# 14      1628372             31  Missed Shot
# 15      1628372             35    Made Shot
# 16      1628372             22  Missed Shot
# 17      1628372             22  Missed Shot
# 18      1628372              8  Missed Shot
# 19      1628372             22    Made Shot
# 20      1628372             20  Missed Shot
# 21      1628372             12    Made Shot
# 22      1628372             22    Made Shot
# 23      1628372             20  Missed Shot
# 24      1628372             20    Made Shot
# 25      1628372             20  Missed Shot
# 26      1628372             19  Missed Shot
# 27      1628372             31  Missed Shot
# 28      1628372             20  Missed Shot
# 29      1628372             12    Made Shot
# ...         ...            ...          ...
# 2914    1629011              3    Made Shot
# 2915    1629011              4    Made Shot
# 2916    1629011             36    Made Shot
# 2917    1629011             36  Missed Shot
# 2918    1629011             24  Missed Shot
# 2919    1629011             28    Made Shot
# 2920    1629011              3    Made Shot
# 2921    1629011             24  Missed Shot
# 2922    1629011             23    Made Shot
# 2923    1629011             14    Made Shot
# 2924    1629011             14    Made Shot
# 2925    1629011              1    Made Shot
# 2926    1629011              3    Made Shot
# 2927    1629011              1    Made Shot
# 2928    1629011              1    Made Shot
# 2929    1629011              1    Made Shot
# 2930    1629011             24    Made Shot
# 2931    1629011             37  Missed Shot
# 2932    1629011             25    Made Shot
# 2933    1629011              1  Missed Shot
# 2934    1629011             24    Made Shot
# 2935    1629011             14    Made Shot
# 2936    1629011             20  Missed Shot
# 2937    1629011              1  Missed Shot
# 2938    1629011             14    Made Shot
# 2939    1629011              1    Made Shot
# 2940    1629011              1    Made Shot
# 2941    1629011              1    Made Shot
# 2942    1629011              1  Missed Shot
# 2943    1629011              1    Made Shot
#
# [2944 rows x 3 columns]

# %%
# Assign X (data) and y (target)
X = shots.drop("event_type", axis=1)
y = shots["event_type"]
print(X.shape, y.shape)
# Out:
# (2944, 2) (2944,)

# %% [markdown]
# Split our data into training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, stratify=y)

# %% [markdown]
# Create a Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Fit (train) or model using the training data

# %%
classifier.fit(X_train, y_train)
# Out:
# C:\Users\antho\Anaconda4\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# Validate the model using the test data

# %%
print(f"Training Data Score: {classifier.score(X_train, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test, y_test)}")
# Out:
# Training Data Score: 0.5280797101449275
# Testing Data Score: 0.5285326086956522

# %% [markdown]
# Make predictions

# %%
predictions = classifier.predict(X_test)
print(f"First 10 Predictions:   {predictions[:10]}")
print(f"First 10 Actual labels: {y_test[:10].tolist()}")
# Out:
# First 10 Predictions:   ['Missed Shot' 'Made Shot' 'Missed Shot' 'Missed Shot' 'Made Shot'
#  'Made Shot' 'Missed Shot' 'Missed Shot' 'Missed Shot' 'Missed Shot']
# First 10 Actual labels: ['Missed Shot', 'Made Shot', 'Made Shot', 'Missed Shot', 'Missed Shot', 'Missed Shot', 'Made Shot', 'Made Shot', 'Made Shot', 'Made Shot']

# %%
pd.DataFrame({"Prediction": predictions, "Actual": y_test}).reset_index(drop=True)
# Out:
#       Prediction       Actual
# 0    Missed Shot  Missed Shot
# 1      Made Shot    Made Shot
# 2    Missed Shot    Made Shot
# 3    Missed Shot  Missed Shot
# 4      Made Shot  Missed Shot
# 5      Made Shot  Missed Shot
# 6    Missed Shot    Made Shot
# 7    Missed Shot    Made Shot
# 8    Missed Shot    Made Shot
# 9    Missed Shot    Made Shot
# 10     Made Shot    Made Shot
# 11   Missed Shot  Missed Shot
# 12   Missed Shot    Made Shot
# 13   Missed Shot    Made Shot
# 14   Missed Shot  Missed Shot
# 15   Missed Shot  Missed Shot
# 16   Missed Shot  Missed Shot
# 17   Missed Shot    Made Shot
# 18     Made Shot  Missed Shot
# 19   Missed Shot    Made Shot
# 20     Made Shot    Made Shot
# 21   Missed Shot  Missed Shot
# 22   Missed Shot  Missed Shot
# 23   Missed Shot    Made Shot
# 24     Made Shot    Made Shot
# 25     Made Shot  Missed Shot
# 26   Missed Shot  Missed Shot
# 27     Made Shot    Made Shot
# 28   Missed Shot    Made Shot
# 29     Made Shot  Missed Shot
# ..           ...          ...
# 706    Made Shot  Missed Shot
# 707    Made Shot    Made Shot
# 708  Missed Shot  Missed Shot
# 709  Missed Shot    Made Shot
# 710    Made Shot  Missed Shot
# 711  Missed Shot  Missed Shot
# 712  Missed Shot  Missed Shot
# 713  Missed Shot    Made Shot
# 714    Made Shot    Made Shot
# 715    Made Shot  Missed Shot
# 716  Missed Shot  Missed Shot
# 717  Missed Shot  Missed Shot
# 718  Missed Shot  Missed Shot
# 719  Missed Shot    Made Shot
# 720    Made Shot  Missed Shot
# 721    Made Shot    Made Shot
# 722  Missed Shot  Missed Shot
# 723  Missed Shot  Missed Shot
# 724  Missed Shot  Missed Shot
# 725    Made Shot  Missed Shot
# 726  Missed Shot    Made Shot
# 727    Made Shot  Missed Shot
# 728  Missed Shot  Missed Shot
# 729    Made Shot  Missed Shot
# 730  Missed Shot  Missed Shot
# 731  Missed Shot    Made Shot
# 732  Missed Shot  Missed Shot
# 733  Missed Shot    Made Shot
# 734  Missed Shot    Made Shot
# 735  Missed Shot  Missed Shot
#
# [736 rows x 2 columns]
