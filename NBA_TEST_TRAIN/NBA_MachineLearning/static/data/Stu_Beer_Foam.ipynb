# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.isotonic import IsotonicRegression

# %% [markdown]
# ## Dataset: beer_foam.csv
#
# Source: J.J. Hackbarth (2006). "Multivariate Analyses of Beer Foam Stand,"
# Journal of the Institute of Brewing, Vol. 112, #1, pp. 17-24
#
# Description: Measurements of wet foam height and beer height at various
# time points for Shiner Bock at 20C. Author fits exponential decay model:
# H(t) = H(0)*exp(-lambda*t)
#
# Variables/Columns
# TIME: Time from pour (seconds)  4-8
# FOAM: Wet foam height (cm)  10-16
# BEER: Beer height (cm)    18-24
#
# **Hypothesis**: Can we predict the time from pour using the measurements of foam height and beer height?

# %%
# Read the csv file into a pandas DataFrame

shots = pd.read_csv('NBA_All.csv')
shots
# Out:
#                       action_type current_team   event_type   game_date  \
# 0                       Jump Shot       Sixers    Made Shot  20181017.0
# 1                       Jump Shot       Sixers  Missed Shot  20181017.0
# 2              Running Layup Shot       Sixers    Made Shot  20181017.0
# 3                       Jump Shot       Sixers  Missed Shot  20181017.0
# 4              Floating Jump shot       Sixers  Missed Shot  20181017.0
# 5                      Layup Shot       Sixers  Missed Shot  20181017.0
# 6              Cutting Layup Shot       Sixers    Made Shot  20181017.0
# 7                       Jump Shot       Sixers  Missed Shot  20181017.0
# 8              Running Layup Shot       Sixers    Made Shot  20181017.0
# 9                       Jump Shot       Sixers  Missed Shot  20181017.0
# 10             Floating Jump shot       Sixers    Made Shot  20181017.0
# 11                      Jump Shot       Sixers  Missed Shot  20181017.0
# 12                      Jump Shot       Sixers    Made Shot  20181017.0
# 13       Turnaround Fadeaway shot       Sixers  Missed Shot  20181019.0
# 14           Turnaround Jump Shot       Sixers    Made Shot  20181019.0
# 15       Turnaround Fadeaway shot       Sixers    Made Shot  20181019.0
# 16              Cutting Dunk Shot       Sixers    Made Shot  20181019.0
# 17      Running Pull-Up Jump Shot       Sixers    Made Shot  20181019.0
# 18                     Layup Shot       Sixers  Missed Shot  20181019.0
# 19                      Jump Shot       Sixers  Missed Shot  20181019.0
# 20                     Layup Shot       Sixers  Missed Shot  20181019.0
# 21                 Hook Bank Shot       Sixers  Missed Shot  20181019.0
# 22               Pullup Jump shot       Sixers  Missed Shot  20181019.0
# 23                      Jump Shot       Sixers  Missed Shot  20181019.0
# 24           Alley Oop Layup shot       Sixers  Missed Shot  20181019.0
# 25                      Jump Shot       Sixers  Missed Shot  20181019.0
# 26                     Layup Shot       Sixers  Missed Shot  20181019.0
# 27                      Jump Shot       Sixers  Missed Shot  20181019.0
# 28               Pullup Jump shot       Sixers  Missed Shot  20181019.0
# 29                      Jump Shot       Sixers    Made Shot  20181019.0
# ...                           ...          ...          ...         ...
# 117891         Cutting Layup Shot      Wizards    Made Shot  20190403.0
# 117892         Driving Layup Shot      Wizards  Missed Shot  20190403.0
# 117893                 Layup Shot      Wizards    Made Shot  20190405.0
# 117894                  Jump Shot      Wizards    Made Shot  20190405.0
# 117914 ...                   1.0           15.0             1.0
# 117915 ...                   1.0            1.0             1.0
# 117916 ...                   1.0            1.0             1.0
# 117917 ...                   1.0           25.0             1.0
# 117918 ...                   1.0            0.0             1.0
# 117919 ...                   1.0            1.0             1.0
# 117920 ...                   1.0           23.0             0.0
#
#              shot_type         shot_zone_area        shot_zone_basic  \
# 0       3PT Field Goal           Left Side(L)          Left Corner 3
# 1       2PT Field Goal           Left Side(L)              Mid-Range
# 2       2PT Field Goal              Center(C)        Restricted Area
# 3       3PT Field Goal  Right Side Center(RC)      Above the Break 3
# 4       2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 5       2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 6       2PT Field Goal              Center(C)        Restricted Area
# 7       3PT Field Goal          Right Side(R)         Right Corner 3
# 8       2PT Field Goal              Center(C)        Restricted Area
# 9       3PT Field Goal          Right Side(R)         Right Corner 3
# 10      2PT Field Goal           Left Side(L)  In The Paint (Non-RA)
# 11      3PT Field Goal              Center(C)      Above the Break 3
# 12      3PT Field Goal              Center(C)      Above the Break 3
# 13      2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 14      2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 15      2PT Field Goal           Left Side(L)              Mid-Range
# 16      2PT Field Goal              Center(C)        Restricted Area
# 17      3PT Field Goal              Center(C)      Above the Break 3
# 18      2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 19      3PT Field Goal  Right Side Center(RC)      Above the Break 3
# 20      2PT Field Goal              Center(C)        Restricted Area
# 21      2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 22      2PT Field Goal              Center(C)              Mid-Range
# 23      3PT Field Goal          Right Side(R)         Right Corner 3
# 24      2PT Field Goal              Center(C)        Restricted Area
# 25      3PT Field Goal   Left Side Center(LC)      Above the Break 3
# 26      2PT Field Goal              Center(C)        Restricted Area
# 27      3PT Field Goal              Center(C)      Above the Break 3
# 28      2PT Field Goal              Center(C)              Mid-Range
# 29      3PT Field Goal   Left Side Center(LC)      Above the Break 3
# ...                ...                    ...                    ...
# 117891  2PT Field Goal              Center(C)        Restricted Area
# 117892  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 117893  2PT Field Goal              Center(C)        Restricted Area
# 117894  3PT Field Goal   Left Side Center(LC)      Above the Break 3
# 117895  2PT Field Goal              Center(C)        Restricted Area
# 117896  2PT Field Goal              Center(C)        Restricted Area
# 117897  2PT Field Goal              Center(C)        Restricted Area
# 117898  2PT Field Goal              Center(C)        Restricted Area
# 117899  2PT Field Goal              Center(C)        Restricted Area
# 117900  3PT Field Goal              Center(C)      Above the Break 3
# 117901  2PT Field Goal              Center(C)        Restricted Area
# 117902  3PT Field Goal              Center(C)      Above the Break 3
# 117903  2PT Field Goal              Center(C)        Restricted Area
# 117904  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 117905  3PT Field Goal              Center(C)      Above the Break 3
# 117906  2PT Field Goal              Center(C)        Restricted Area
# 117907  2PT Field Goal              Center(C)        Restricted Area
# 117908  2PT Field Goal              Center(C)        Restricted Area
# 117909  2PT Field Goal              Center(C)        Restricted Area
# 117910  3PT Field Goal  Right Side Center(RC)      Above the Break 3
# 117911  2PT Field Goal              Center(C)        Restricted Area
# 117912  2PT Field Goal              Center(C)  In The Paint (Non-RA)
# 117913  2PT Field Goal              Center(C)        Restricted Area
# 117914  2PT Field Goal           Left Side(L)              Mid-Range
# 117915  2PT Field Goal              Center(C)        Restricted Area
# 117916  2PT Field Goal              Center(C)        Restricted Area
# 117917  3PT Field Goal              Center(C)      Above the Break 3
# 117918  2PT Field Goal              Center(C)        Restricted Area
# 117919  2PT Field Goal              Center(C)        Restricted Area
# 117920  3PT Field Goal          Right Side(R)         Right Corner 3
#
#         shot_zone_range       team_id           team_name  vtm
# 0               24+ ft.  1.610613e+09         LA Clippers  DEN
# 1              8-16 ft.  1.610613e+09         LA Clippers  DEN
# 2       Less Than 8 ft.  1.610613e+09         LA Clippers  DEN
# 3               24+ ft.  1.610613e+09         LA Clippers  DEN
# 4              8-16 ft.  1.610613e+09         LA Clippers  DEN
# 5       Less Than 8 ft.  1.610613e+09         LA Clippers  DEN
# 6       Less Than 8 ft.  1.610613e+09         LA Clippers  DEN
# 7               24+ ft.  1.610613e+09         LA Clippers  DEN
# 8       Less Than 8 ft.  1.610613e+09         LA Clippers  DEN
# 9               24+ ft.  1.610613e+09         LA Clippers  DEN
# 10             8-16 ft.  1.610613e+09         LA Clippers  DEN
# 11              24+ ft.  1.610613e+09         LA Clippers  DEN
# 12              24+ ft.  1.610613e+09         LA Clippers  DEN
# 13      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 14             8-16 ft.  1.610613e+09         LA Clippers  OKC
# 15             8-16 ft.  1.610613e+09         LA Clippers  OKC
# 16      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 17              24+ ft.  1.610613e+09         LA Clippers  OKC
# 18      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 19              24+ ft.  1.610613e+09         LA Clippers  OKC
# 20      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 21      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 22             8-16 ft.  1.610613e+09         LA Clippers  OKC
# 23              24+ ft.  1.610613e+09         LA Clippers  OKC
# 24      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 25              24+ ft.  1.610613e+09         LA Clippers  OKC
# 26      Less Than 8 ft.  1.610613e+09         LA Clippers  OKC
# 27              24+ ft.  1.610613e+09         LA Clippers  OKC
# 28            16-24 ft.  1.610613e+09         LA Clippers  OKC
# 29              24+ ft.  1.610613e+09         LA Clippers  OKC
# ...                 ...           ...                 ...  ...
# 117891  Less Than 8 ft.  1.610613e+09  Washington Wizards  CHI
# 117892  Less Than 8 ft.  1.610613e+09  Washington Wizards  CHI
# 117893  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117894          24+ ft.  1.610613e+09  Washington Wizards  SAS
# 117895  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117896  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117897  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117898  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117899  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117900          24+ ft.  1.610613e+09  Washington Wizards  SAS
# 117901  Less Than 8 ft.  1.610613e+09  Washington Wizards  SAS
# 117902          24+ ft.  1.610613e+09  Washington Wizards  SAS
# 117903  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117904  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117905          24+ ft.  1.610613e+09  Washington Wizards  WAS
# 117906  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117907  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117908  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117909  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117910          24+ ft.  1.610613e+09  Washington Wizards  WAS
# 117911  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117912  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117913  Less Than 8 ft.  1.610613e+09  Washington Wizards  WAS
# 117914         8-16 ft.  1.610613e+09  Washington Wizards  BOS
# 117915  Less Than 8 ft.  1.610613e+09  Washington Wizards  BOS
# 117916  Less Than 8 ft.  1.610613e+09  Washington Wizards  BOS
# 117917          24+ ft.  1.610613e+09  Washington Wizards  BOS
# 117918  Less Than 8 ft.  1.610613e+09  Washington Wizards  BOS
# 117919  Less Than 8 ft.  1.610613e+09  Washington Wizards  BOS
# 117920          24+ ft.  1.610613e+09  Washington Wizards  BOS
#
# [117921 rows x 26 columns]

# %%
# Assign the data to X and y

X = shots[["shot_distance", "loc_x"]]
y = shots["shot_made_flag"]
print(X.shape, y.shape)
# Out:
# (117921, 2) (117921,)

# %%
# Use train_test_split to create training and testing data

### BEGIN SOLUTION
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y)

### END SOLUTION

# %%
# Create the model using LinearRegression

### BEGIN SOLUTION
from sklearn.linear_model import LinearRegression
model = LinearRegression()
### END SOLUTION

# %%
# Fit the model to the training data and calculate the scores for the training and testing data

### BEGIN SOLUTION
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

### END SOLUTION 

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-307baa1eb026> in <module>
#       2
#       3 ### BEGIN SOLUTION
# ----> 4 model.fit(X_train, y_train)
#       5 training_score = model.score(X_train, y_train)
#       6 testing_score = model.score(X_test, y_test)
#
# ~\Anaconda4\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     456         n_jobs_ = self.n_jobs
#     457         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 458                          y_numeric=True, multi_output=True)
#     459
#     460         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda4\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     754                     ensure_min_features=ensure_min_features,
#     755                     warn_on_dtype=warn_on_dtype,
# --> 756                     estimator=estimator)
#     757     if multi_output:
#     758         y = check_array(y, 'csr', force_all_finite=True, ensure_2d=False,
#
# ~\Anaconda4\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     571         if force_all_finite:
#     572             _assert_all_finite(array,
# --> 573                                allow_nan=force_all_finite == 'allow-nan')
#     574
#     575     shape_repr = _shape_repr(array.shape)
#
# ~\Anaconda4\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan)
#      54                 not allow_nan and not np.isfinite(X).all()):
#      55             type_err = 'infinity' if allow_nan else 'NaN, infinity'
# ---> 56             raise ValueError(msg_err.format(type_err, X.dtype))
#      57
#      58
#
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').

# %%
# Plot the Residuals for the Training and Testing data

### BEGIN SOLUTION
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot")
### END SOLUTION
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# <ipython-input-22-da2d3724be16> in <module>
#       2
#       3 ### BEGIN SOLUTION
# ----> 4 plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
#       5 plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
#       6 plt.legend()
#
# ~\Anaconda4\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     211             Returns predicted values.
#     212         """
# --> 213         return self._decision_function(X)
#     214
#     215     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda4\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     192
#     193     def _decision_function(self, X):
# --> 194         check_is_fitted(self, "coef_")
#     195
#     196         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#
# ~\Anaconda4\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#     949
#     950     if not all_or_any([hasattr(estimator, attr) for attr in attributes]):
# --> 951         raise NotFittedError(msg % {'name': type(estimator).__name__})
#     952
#     953
#
# NotFittedError: This LinearRegression instance is not fitted yet. Call 'fit' with appropriate arguments before using this method.
